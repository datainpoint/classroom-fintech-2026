# %% [markdown]
# # 資料、模型與神經網路的紀元 The Era of Data, Model, and Neural Network
#
# > 台灣金融研訓院芬恩特，2026-03-25
#
# [郭耀仁](https://hahow.in/@tonykuoyj?tr=tonykuoyj) | <yaojenkuo@ntu.edu.tw>

# %% [markdown]
# ## 關於講者：郭耀仁
#
# - 資料科學的專業講師，在 [Hahow 好學校](https://hahow.in/@tonykuoyj?tr=tonykuoyj) 開設七堂線上課程，共有七千多名學生。
# - 實體課程：台大工商管理學系、台大共同教育中心、台大資工系統訓練班、中華電信學院。
# - 講授過兆豐銀行、星展銀行、華南銀行與玉山銀行的 Python 工作坊。
# - 在擔任專業講師前曾於酷澎（Coupang）、賽仕電腦（SAS）與中國信託（CTBC）任職；畢業自台灣大學商學研究所。
# - 閒暇時喜歡長跑與桌球。

# %% [markdown]
# ## 21 世紀最性感的職業：資料科學家
#
# > Data Scientist: The Sexiest Job of the 21st Century.
# >
# > Harvard Business Review, October 2012.

# %% [markdown]
# ## 資料科學家並不是一個橫空出世的職業
#
# > Monica Geller-Bing : I want you to have a job that you love not statistical analysis and data reconfiguration.
# >
# > Chandler Bing : I quit, and you learn what I do?
#
# 來源：<https://www.imdb.com/title/tt0583470/characters/nm0001612>

# %% [markdown]
# ## 資料科學也不是一個橫空出世的學科
#
# - [Fortran](https://en.wikipedia.org/wiki/Fortran) 於 1957 問世。
# - [Hidden Figures](https://en.wikipedia.org/wiki/Hidden_Figures) 講述到科學計算與 Fortran
# - [SAS](https://en.wikipedia.org/wiki/SAS_(software)) 於 1972 問世。
# - [SQL](https://en.wikipedia.org/wiki/SQL) 於 1973 問世。
# - [Matlab](https://www.mathworks.com/products/matlab.html) 於 1984 問世。

# %% [markdown]
# ## 年輕的資料科學：科學計算、資料探勘、統計分析
#
# - 關聯式資料庫。
# - 試算表軟體。
# - 科學計算軟體、語言。
# - 商業智慧。

# %% [markdown]
# ## 推動業界資訊化、資料化的編年史
#
# - 1970s 到 2000s
#     - 單機應用程式。
#     - 關聯式資料庫。
#     - 科學計算。
#     - 資料探勘。
# - 2010s 到 2020s
#     - 網頁應用程式。
#     - 非關聯式資料庫（No-SQL）。
#     - 大數據。
#     - 資料科學。
#     - 機器學習。
#     - 深度學習。
#     - 人工智慧。

# %% [markdown]
# ## 簡單粗暴的 Buzz word：大數據
#
# > Big Data: A Revolution That Will Transform How We Live, Work, and Think
# >
# > Viktor Mayer-Schönberger, Kenneth Cukier, March, 2013.

# %% [markdown]
# ## 大數據時代的明星
#
# - [Hadoop Distributed File System](https://en.wikipedia.org/wiki/Apache_Hadoop)
# - [MapReduce](https://en.wikipedia.org/wiki/MapReduce)
# - [Spark](https://en.wikipedia.org/wiki/Apache_Spark)
# - [Java](https://en.wikipedia.org/wiki/Java_(programming_language))
# - [Scala](https://en.wikipedia.org/wiki/Scala_(programming_language))

# %% [markdown]
# ## 資料科學/資料科學家的迷因圖
#
# ![Imgur](https://i.imgur.com/vbczHMF.jpg)

# %% [markdown]
# ## 成熟的資料科學：「六加一」管線流
#
# ![Imgur](https://i.imgur.com/din6Ig6.png)

# %% [markdown]
# ## 資料科學時代的明星
#
# - Python
#     - Numpy
#     - Pandas
#     - Matplotlib
# - R
#     - `Data.Frame`
#     - Caret
# - [D3.js](https://en.wikipedia.org/wiki/D3.js)
# - MongoDB

# %% [markdown]
# ## 模型、函數與機器學習
#
# - 以「物件」實現「類別」的思維。
# - 描繪「輸入」與「輸出」的映射關係。
# - 以「資料」生成「參數」的訓練技巧。

# %% [markdown]
# ## 機器學習的「三加一」
#
# > A computer program is said to learn from experience E with respect to some class of tasks T and performance measure P if its performance at tasks in T, as measured by P, improves with experience E.
# >
# > Machine Learning by Tom Mitchell, 1997

# %% [markdown]
# ## 機器學習不是一門橫空出世的學科
#
# - 貝氏定理於 1700s 問世。
# - 迴歸分析於 1800s 問世。
# - 聚類演算法於 1950s 問世。
# - 決策樹演算法於 1960s 問世。
# - 支援向量機於 1990s 問世。

# %% [markdown]
# ## 傳統軟體 Software 1.0
#
# ![Imgur](https://i.imgur.com/3pojPXW.png?1)

# %% [markdown]
# ## 基於機器學習的軟體 Software 2.0
#
# ![Imgur](https://i.imgur.com/YunyLd7.png)

# %% [markdown]
# ## 用方程式表達機器學習
#
# \begin{equation}
# \text{choose} \; w \in \{w^1, w^2, ..., w^n\} \\
# \text{where} \; w \; \text{minimizes} \; J(w) \\
# \text{subject to} \; \hat{y} = h(X; w) = Xw \\
# \text{where} \; J(w) \; \text{measures the loss between} \; y \; \text{and} \; \hat{y} \\
# \end{equation}

# %% [markdown]
# ## 以「梯度遞減」演算法求解 $w$
#
# \begin{equation}
# \text{for} \; \text{each} \; \text{epoch:} \\
# w := w - \alpha \frac{\partial J}{\partial w} \\
# \text{where } \alpha > 0
# \end{equation}

# %% [markdown]
# ## 何時採用 Software 1.0
#
# - 問題能用人類語言描述邏輯、撰寫規則。
# - 答案不能容忍誤差。
# - e.g. 給定整數判斷它是奇數、偶數或者質數。

# %% [markdown]
# ## 何時採用 Software 2.0
#
# - 問題非領域專家不容易描述邏輯、撰寫規則。
# - 答案能夠容忍誤差。
# - e.g. 給定一間房子的坪數、防廳衛浴數、車位與所在位置等資訊來判斷房價。

# %% [markdown]
# ## 機器學習時代的明星
#
# - Machine Learning by Andrew Ng
# - [Kaggle](https://www.kaggle.com/)
# - Python
#     - [Scikit-Learn](https://scikit-learn.org/)
#         - Support Vector Machine
#         - Decision Tree
#         - Random Forest
#         - Ensemble Learning
#     - [Natural Language Toolkit](https://www.nltk.org/)
#     - [XGBoost](https://xgboost.readthedocs.io/en/stable/index.html)

# %% [markdown]
# ## 機器學習時代明星演算法表現很好的任務
#
# - 陣列、表格形式的資料。
# - 線性可分的資料。
# - 數值預測。
# - 聚類與主成份分析。
# - 輸入與輸出沒有遞迴關係。

# %% [markdown]
# ## 深度學習時代的來臨：突破機器學習表現不夠好的任務
#
# - 表現不夠好的任務：
#     - 難以用言語描述規則的任務：電腦視覺。
#     - 輸入與輸出有遞迴關係：時間序列、自然語言、強化學習。
# - 深度學習是機器學習的一個分支，是一種不需要使用者直接決定特徵的演算法，改由深度學習的結構間接決定。
# - 人類能夠輕易做到小規模，但是想大規模處理會曠日費時的任務（例如翻譯、影像辨識）。

# %% [markdown]
# ## 深度學習也不是一門橫空出世的學科
#
# - 感知器（Perceptron）於 1950s 問世。
# - 反向傳播演算法（Backpropagation）於 1970s 問世。
# - 遞歸神經網路（Recurrent Neural Network）於 1970s 問世。
# - 卷積神經網路（Convolutional Neural Network）於 1980s 問世。

# %% [markdown]
# ## 以神經網路的層數與神經元個數進行特徵學習
#
# - 機器學習的特徵工程 Feature Engineering 對比深度學習的特徵學習 Feature Learning
# - 由使用者以「層數」、「每層的神經元個數」定義結構來決定特徵個數。
#
# \begin{align}
# \hat{Y} &= h(X; W) \\
# &= h^{(n)}(...h^{(2)}(h^{(1)}(X; W^{(1)})))
# \end{align}

# %% [markdown]
# ## 輸入層、輸出層與隱藏層
#
# - 其中 $h^{(1)}$ 稱為「輸入層」（Input layer），$ h^{(n)}$ 稱為「輸出層」（Output layer），介於這兩層之間的 $h^{(i)}$ 則稱為「隱藏層」（Hidden layer）。
# - 深度學習模型與傳統機器學習模型最大的差別，就在於是否有隱藏層的存在，意即一個最基本、最淺的深度學習模型至少具有三層。

# %% [markdown]
# ## 深度學習模型的係數
#
# - 隱藏層造就了尋找深度學習模型最適的 $W$ 時，需要採用「反向傳播」（Backpropagation）的演算法。
# - 隱藏層的存在，導致了 $\hat{Y}$ 與 $Y$ 之間的誤差僅能回饋到前一個隱藏層與輸出層之間的 $W$ 作為更新依據，更前段層數之間 $W$ 的更新依據，則改由後段層數回饋。
# - 簡言之，我們可以將反向傳播類比為專門設計給深度學習模型的梯度遞減演算法。

# %% [markdown]
# ## 一個最基礎的深度學習模型
#
# 會有輸入層、隱藏層與輸出層至少三層的深度，透過各層之間的單位相連接，可以得到 $W^{(i)}$ 的係數，這組係數經過訓練之後，可以將輸入的特徵矩陣 $X$ 映射為目標矩陣 $\hat{Y}$。每層都是由啟動函數、前一層的輸出、當層的係數結合，然後成為下一層的輸入。
#
# \begin{align}
# Z^{(1)} &= W^{(1)}A^{(0)} = W^{(1)}X^{T} \\
# A^{(1)} &= \sigma(Z^{(1)}) \\
# Z^{(2)} &= W^{(2)}A^{(1)} \\
# A^{(2)} &= \sigma(Z^{(2)}) = \hat{Y}
# \end{align}

# %% [markdown]
# ## 深度學習模型的訓練
#
# - 我們可以應用連鎖法則（Chain rule）求解它關於各參數層之偏微分，以一個具有三層結構的深度學習模型為例，反向傳播會先更新「隱藏至輸出」階段中的 $W^{(1)}$
#
# \begin{align}
# \frac{\partial J}{\partial W^{(1)}} = \frac{\partial J}{\partial A^{(1)}} \frac{\partial A^{(1)}}{\partial Z^{(1)}} \frac{\partial Z^{(1)}}{\partial W^{(1)}}
# \end{align}
#
# - 再返回更新「輸入至隱藏」階段中的 $W^{(0)}$
#
# \begin{align}
# \frac{\partial J}{\partial W^{(0)}} = \frac{\partial J}{\partial A^{(1)}} \frac{\partial A^{(1)}}{\partial Z^{(1)}} \frac{\partial Z^{(1)}}{\partial A^{(0)}} \frac{\partial A^{(0)}}{\partial Z^{(0)}} \frac{\partial Z^{(0)}}{\partial W^{(0)}}
# \end{align}

# %% [markdown]
# ## 深度學習時代的明星
#
# - Deep Learning by Andrew Ng
# - Convolutional Neural Network(CNN)
# - Recurrent Neural Network(RNN)
#     - Long Short-Term Memory(LSTM)
# - Python
#     - [TensorFlow](https://www.tensorflow.org)
#         - [Keras](https://keras.io)
#     - [PyTorch](https://pytorch.org)

# %% [markdown]
# ## 人工智慧時代的來臨：在自然語言大幅突破
#
# - 深度學習的強項為言語難以描述規則的任務：電腦視覺、自然語言與強化學習。
# - 自然語言的場景：
#     - 語言模型：機器翻譯、問答、摘要。
#     - 輸入文字輸出圖片。
#     - 音訊：輸入文字輸出音訊、輸入音訊輸出文字。

# %% [markdown]
# ![](01.png)

# %% [markdown]
# ## 為什麼讓電腦理解自然語言是困難的
#
# - 電腦只認得數值，必須將文字轉換為數值（或者由數值組成的資料結構）。
# - 機器學習模型若要將文字型態變數納入特徵矩陣，必須做編碼轉換。
# - 常見編碼轉換有 One-hot encoder、Dummy encoder
# - 但是這樣的編碼轉換僅限應用於有限組別的類別資料（nominal categorical data）。

# %% [markdown]
# ## 對自然語言來說，理想的編碼轉化
#
# - 將單詞以 n 維的「數值向量」表示，又稱詞向量（Word vectors, word embeddings）。
# - 詞向量之間的相似度要能夠反映「同義詞」、「相近詞」、「反義詞」。

# %% [markdown]
# ## 透過深度學習模型將單詞轉換為詞向量
#
# - Word2Vec
# - GloVe
# - FastText
# - ELMo
# - BERT
# - ...etc.

# %% [markdown]
# ## 讓電腦理解自然語言仍舊是困難的
#
# - 除了編碼轉換這個難題，尚有詞彙連貫性的難題待解。
# - RNN 與 LSTM 神經網路就是在解決連貫性的問題。
# - 大型語言模型的核心 Transformer 則是以 Attention 在詞彙連貫性獲得突破性進展。
# - [Attention Is All You Need](https://arxiv.org/abs/1706.03762) 並不是「發明」了 Attention 注意力機制，而是提出過往一直認定的 RNN + Attention 實際上僅需要 Attention 就好。

# %% [markdown]
# ## 搭建大型語言模型的步驟
#
# - Tokenization：斷詞斷句。
# - Embedding：從詞到詞向量。
# - 堆疊 `n` 個 Transformer 單位。
# - 輸出層：`Softmax()` 函數得到下一個詞向量的機率。

# %% [markdown]
# ## 大型語言模型的運作，可以使用 `GPT-2` 快速理解
#
# <https://colab.research.google.com/drive/1pAhu8RinqoeTsrV7q9kFwRmY9ahKV3mX?usp=sharing>

# %% [markdown]
# ## 大型語言模型是人工智慧時代的主角
#
# - 基於大型語言模型（Large Language Models）的知名服務有：OpenAI ChatGPT, Google Gemini, Anthropic Claude and xAI Grok...等。
# - 「大型」的命名原因是由於這些模型具備了數百萬、數十億個參數。
#
# 來源：<https://informationisbeautiful.net/visualizations/the-rise-of-generative-ai-large-language-models-llms-like-chatgpt/>

# %% [markdown]
# ## 什麼是參數 $w$
#
# \begin{equation}
# \text{choose} \; w \in \{w^1, w^2, ..., w^n\} \\
# \text{where} \; w \; \text{minimizes} \; J(w) \\
# \text{subject to} \; \hat{y} = h(X; w) = Xw \\
# \text{where} \; J(w) \; \text{measures the loss between} \; y \; \text{and} \; \hat{y} \\
# \end{equation}

# %% [markdown]
# ## 僅有兩個參數的模型：用坪數 $w_1$ 預測房價 $\hat{y}$
#
# - $w_0$ 是常數（$x_0 = 1$）的參數。
# - $w_1$ 是坪數（$x_1$）的參數。
#
# \begin{equation}
# \hat{y} = w_0x_0 + w_1x_1
# \end{equation}

# %% [markdown]
# ## 有 785 個參數的模型：用像素 $w_n$ 預測一個 28x28 圖片內容 $\hat{y}$
#
# - $w_0$ 是常數（$x_0 = 1$）的參數。
# - $w_n$ 是第 n 個像素（$x_n$）的參數。
#
# \begin{equation}
# \hat{y} = w_0x_0 + ... + w_{784}x_{784}
# \end{equation}

# %% [markdown]
# ## 在 Transformer 之前
#
# - 不同的神經網路架構（深度學習模型）有著各自擅長的領域：
#     - FNN: 結構化資料。
#     - CNN: 電腦視覺。
#     - RNN/LSTM: 自然語言、時間序列。
# - RNN/LSTM 可以生成合適的單字元、單詞，但在生成長篇幅的文章上會顯其劣勢（效能、連貫性的弱化）。

# %% [markdown]
# ## 基於大型語言的軟體 Software 3.0
#
# - 從 [GitHub](https://github.com/) Repositories 到 [Hugging Face](https://huggingface.co/) Models
# - 從 Fork 到 Fine-tuning
# - 從雲端環境到代理人開發：[Replit](https://replit.com/)

# %% [markdown]
# ## 人工智慧時代的明星
#
# - NVIDIA
# - OpenAI ChatGPT
# - Anthropic Claude
# - Google Gemini
# - xAI Grok
# - ...etc.

# %% [markdown]
# ## 科技巨頭的人工智慧競爭：Meta's Mark Zuckerberg
#
# > "I’d rather build capacity before it is needed rather than too late."
# >
# > "Part of what’s important about A.I. is that it can be used to improve all of our products in almost every way."
# >
# > Mark Zuckerberg
#
# 來源：<https://www.nytimes.com/2024/07/31/technology/meta-earnings-artificial-intelligence.html>

# %% [markdown]
# ## 科技巨頭的人工智慧競爭：Tesla's Elon Musk
#
# Elon Musk is spending \\$10 billion this year(2024) alone to bulk up on AI training and inference, and position Tesla at the forefront of the industry for real-life applications outside of generative AI.
#
# > "Any company not spending at this level, and doing so efficiently, cannot compete."
# >
# > Elon Musk
#
# 來源：<https://www.nytimes.com/2024/07/31/technology/meta-earnings-artificial-intelligence.html>

# %% [markdown]
# ## 科技巨頭的人工智慧競爭：OpenAI’s Sam Altman
#
# > "Whether we burn \\$500 million a year or \\$5 billion or \\$50 billion a year I don’t care, I genuinely don’t."
# >
# > "As long as we can figure out a way to pay the bills, we’re making AGI. It’s going to be expensive."
# >
# > Sam Altman
#
# Source: <https://finance.yahoo.com/news/openai-sam-altman-doesn-t-161126520.html>

# %% [markdown]
# ## 大型語言模型的訓練成本逐年升高
#
# |Year|Model|Company|Training Cost(USD)|
# |----|:----|:------|---------:|
# |2017|Transformer|Google|930|
# |2018|BERT-Large|Google|3,288|
# |2019|RoBERTa Large|Meta|160,018|
# |2020|GPT-3 175B (davinci)|OpenAI|4,324,883|
# |2021|Megatron-Turing NLG 530B|Microsoft/Nvidia|6,405,653|
# |2022|LaMDA|Google|	1,319,586|
# |2022|PaLM (540B)|Google|12,389,056|
# |2023|GPT-4|OpenAI|78,352,034|
# |2023|Llama 2 70B|Meta|3,931,897|
# |2023|Gemini Ultra|Google|191,400,000|
# |2025|DeepSeek V3|Hangzhou DeepSeek|6,000,000|
#
# Source: <https://aiindex.stanford.edu/report>

# %% [markdown]
# ## 關於人工智慧應用的問卷調查：Gartner
#
# > 55% of organizations are now experimenting generative AI technologies. Gartner, Inc. poll of more than 1,400 executive leaders, 45% reported that they are in piloting mode with generative AI, and another 10% have put generative AI solutions into production.
#
# 來源：<https://www.gartner.com/en/newsroom/press-releases/2023-10-03-gartner-poll-finds-55-percent-of-organizations-are-in-piloting-or-production-mode-with-generative-ai>

# %% [markdown]
# ## 關於人工智慧應用的問卷調查：Anaconda
#
# > 63% of data specialists are using generative AI technologies. The majority (63%) of data science practitioners said they’re using generative AI the same amount or more now compared to 2022. Many feel their jobs are threatened by generative AI.
# >
# > 85% of enterprises will expand AI with open source models. Many are turning to open source models such as GPT-J, BERT, and FLAN-T5. The release of portable model families such as Llama 2, marketplaces such as Hugging Face, and corporate investments into these initiatives will further accelerate this trend.
#
# 來源：<https://www.anaconda.com/lp/state-of-data-science-report-2023>

# %% [markdown]
# ## 關於人工智慧應用的問卷調查：BCG
#
# > "Boring AI" use cases generate the majority of the value. Knowledge workers utilizing GPT-4 experienced significant enhancements in efficiency and quality, particularly in domains like operations, customer service, legal and compliance, and technology.
#
# 來源：<https://www.bcg.com/publications/2023/assessing-the-impact-of-generative-ai-on-workforce-productivity>

# %% [markdown]
# ## 展望：科技巨頭將持續在人工智慧競爭（以資本支出作為推論依據）
#
# - [Big Tech's AI investments set to spike to \\$364 billion in 2025 as bubble fears ease](https://finance.yahoo.com/news/big-techs-ai-investments-set-to-spike-to-364-billion-in-2025-as-bubble-fears-ease-143203885.html)
# - <https://www.wsj.com/tech/ai/tech-ai-spending-company-valuations-7b92104b>
# - [Tech megacaps plan to spend more than \\$300 billion in 2025 as AI race intensifies](https://www.cnbc.com/2025/02/08/tech-megacaps-to-spend-more-than-300-billion-in-2025-to-win-in-ai.html)

# %% [markdown]
# ## 展望：小型、領域專用的語言模型
#
# - ChatLaw(Law)
# - Med-PaLM 2(Medicine, Google)
# - BloombergGPT(Finance, Bloomberg)
# - Replit Code(Coding, [Replit](https://replit.com))
# - ...etc.

# %% [markdown]
# ## 展望：品質良好的資料造就威力非凡的語言模型
#
# - 728 題 LeetCode、5 種程式語言 C, C++, Java, JavaScript, Python
# - 簡單：89%
# - 中等：71%
# - 困難：40%
#
# 來源：<https://ieeexplore.ieee.org/document/10507163>

# %% [markdown]
# ## 品質良好的資料：以程式設計為例
#
# - 程式設計的基本單位是輸入輸出。
# - 多數的訓練資料都有詳盡的說明文字。
# - 論壇（例如 StackOverflow）的程式碼都有特定的 Highlight
# - 開源、GitHub、LeetCode、StackOverflow 多年的盛行累積了大量品質良好的程式碼、說明文字。

# %% [markdown]
# ## 軟體工程師（領域專家、白領工作者）的價值
#
# - 基本功與最佳實踐（Best practice）
# - 尋找、辨別合適的工具。
# - 問題解決的框架（One bite at a time）。
# - 專案管理。
# - 協作。
# - 溝通與說服。

# %% [markdown]
# ## 展望：軟體工程師不會失去飯碗
#
# > "If you don't have someone who actually understands the business, understands the strategy, helping you work on the right things rather than the wrong things, chances are you won’t be very impactful."
# >
# > Cassie Kozyrkov, Google's first Chief Decision Scientist
# >
# > 我也很愛吃麵包，以前也犯了一樣的錯，可是我認識麵包店叔叔後，才暸解自己做的麵包，遠比偷來的還要美味。
# >
# > 麵包小偷2：誰偷了葡萄乾麵包

# %% [markdown]
# ## 展望：資料科學家不會失去飯碗
#
# - 能夠從事科學計算、資料探勘的 GUI 軟體一直存在。
#     - Microsoft Excel
#     - SAS Enterprice Miner
#     - SPSS
#     - Orange
#     - KNIME
#     - RapidMiner
#     - Weka
# - 資料科學家的工作反而因為資料探勘、大數據、機器學習的盛行而上升。

# %% [markdown]
# ## 展望：領域專家、白領工作者不會失去飯碗
#
# > 一群會計師聚在一起吃飯，聊到 AI 人工智慧未來會不會取代會計師這個行業。其中有一個會計師安慰大家說：「放心啦，東窗事發的時候，總要有人負責進去關，我們不會失業的啦！」
#
# Source: Google Search {會計} {AI} {笑話}

# %% [markdown]
# ## 展望：從語言模型到代理式人工智慧
#
# - 開源代理式 AI：OpenClaw
# - 企業用代理式 AI：NVIDIA NemoClaw、AWS Bedrock Agents、Azure AI Foundry Agent Service
# - 開發者專用代理式 AI：Anthropic Claude Code
# - 自動化流程工具：n8n
# - 輕量化代理式 AI：Nanobot

# %% [markdown]
# ## 到底什麼是 Transformer、GPT？
#
# > Talk is cheap. Show me the code.
# >
# > Linus Torvalds

# %% [markdown]
# ## 我最喜歡的其中一種學習手法是：Build from Scratch
#
# - 我不知道什麼是正規方程？試著實作一個。
# - 我不知道什麼是梯度遞減？試著實作一個。
# - 我不知道什麼是羅吉斯回歸？試著實作一個。
# - 我不知道什麼是 FNN？試著實作一個。
#
# 來源：<https://www.books.com.tw/products/0010867390>

# %% [markdown]
# ## 我不知道什麼是 GPT？試著實作一個！
#
# <https://colab.research.google.com/drive/1pAhu8RinqoeTsrV7q9kFwRmY9ahKV3mX?usp=sharing>
